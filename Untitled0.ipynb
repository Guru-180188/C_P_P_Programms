# %% [markdown]
# <a href="https://colab.research.google.com/github/Guru-180188/C_P_P_Programms/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/ .kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d deadprstkrish/glove6b300d
# Out:
# Downloading glove6b300d.zip to /content
# 100% 385M/386M [00:21<00:00, 20.0MB/s]
# 100% 386M/386M [00:21<00:00, 18.5MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/glove6b300d.zip', 'r')
zip_ref.extractall('/content/data')
zip_ref.close()

# %%
import zipfile
import os

# Specify the path to your zip file
zip_file_path = '/content/drive/MyDrive/text_c10-20240205T075004Z-001.zip'

# Specify the directory where you want to extract the contents
extracted_folder_path = '/content/data'

# Create the extraction folder if it doesn't exist
os.makedirs(extracted_folder_path, exist_ok=True)

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents to the specified directory
    zip_ref.extractall(extracted_folder_path)

print(f"Zip file '{zip_file_path}' has been extracted to '{extracted_folder_path}'.")
# Out:
# Zip file '/content/drive/MyDrive/text_c10-20240205T075004Z-001.zip' has been extracted to '/content/data'.

# %%
import glob
import pandas as pd
import urllib.request
import imageio
import os
import numpy as np
from urllib.request import urlopen

# %%
def loadGloveModel(gloveFile):
    print("Loading Glove Model")
    f = open(gloveFile,'r',encoding="utf8")
    model = {}
    for line in f:
        try:
            splitLine = line.split()
            word = splitLine[0]
            embedding = np.array([float(val) for val in splitLine[1:]])
            model[word] = embedding
        except:
            print(word)
    print("Done.",len(model)," words loaded!")
    return model

# %%
glove_embeddings = loadGloveModel("/content/data/glove.6B.300d.txt")
# Out:
# Loading Glove Model
# Done. 400001  words loaded!

# %%
# Setting up the paths
train_data_path = "/content/drive/MyDrive/flowers/102flowers"
train_images_path = "/content/drive/MyDrive/flowers/102flowers/jpg"
train_captions_path = "/content/data/text_c10"

# %%
# Importing packages
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense, Concatenate
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D, Conv2DTranspose
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras import initializers
from sklearn.metrics import mean_squared_error

import numpy as np
from PIL import Image
from tqdm import tqdm
import os
import time
import matplotlib.pyplot as plt

# %%
# code for formatted time string. This will be used to name the files during training, testing, etc.
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
GENERATE_RES = 2 # Generation resolution factor
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image - These parameters will be used while training the model. We are asking our model to generate png images made up of 28 images in each file.
#Hence we use the rows and cols representation.
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

#test image - These parameters will be used while generation/prediction phase of the model. We are asking our model to generate png images made up of 1 image in each file.
TEST_ROWS=1
TEST_COLS=1
TEST_MARGIN=16

# Size vector to generate images from
SEED_SIZE = 100
EMBEDDING_SIZE = 300

# environment variables providing paths and other paramenters for training and generation
DATA_PATH = train_images_path
MODEL_PATH = "/content/drive/MyDrive/flowers/102flowers/model"
BATCH_SIZE = 64
BUFFER_SIZE = 4000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 64px square images.

# %%
training_binary_path = os.path.join("/content/drive/MyDrive/flowers/102flowers/npy64x64",
                                    f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}_')

start = time.time()
print("Loading training images...")

training_data = []
flowers_path = sorted(os.listdir(DATA_PATH))

for filename in range(len(flowers_path)):
    path = os.path.join(DATA_PATH,flowers_path[filename])
    # print(path)
    try:
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      channel = np.asarray(image).shape[2]
      if channel == 3:
        training_data.append(np.asarray(image))
    except KeyboardInterrupt:
        print("Keyboard Interrup by me...")
        break
    except:
      pass
    if len(training_data) == 100:
      training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
                GENERATE_SQUARE,IMAGE_CHANNELS))
      training_data = training_data.astype(np.float32)
      #Normalizing the input
      training_data = training_data / 127.5 - 1.

      print("Saving training image " + str(100000 + filename) + ".npy")
      np.save(training_binary_path + str(100000 + filename) + ".npy",training_data)
      elapsed = time.time()-start
      print (f'Image preprocess time: {hms_string(elapsed)}')
      training_data = []
print("Complete")
# Out:
# Loading training images...
# <ipython-input-19-9aa83830874b>:15: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   GENERATE_SQUARE),Image.ANTIALIAS)
# Saving training image 100100.npy
# Image preprocess time: 0:04:42.93
# Saving training image 100200.npy
# Image preprocess time: 0:04:44.05
# Saving training image 100300.npy
# Image preprocess time: 0:04:44.99
# Saving training image 100400.npy
# Image preprocess time: 0:04:46.55
# Saving training image 100500.npy
# Image preprocess time: 0:04:47.79
# Saving training image 100600.npy
# Image preprocess time: 0:04:49.01
# Saving training image 100700.npy
# Image preprocess time: 0:04:50.24
# Saving training image 100800.npy
# Image preprocess time: 0:04:51.53
# Saving training image 100900.npy
# Image preprocess time: 0:04:52.77
# Saving training image 101000.npy
# Image preprocess time: 0:04:54.35
# Saving training image 101100.npy
# Image preprocess time: 0:04:55.59
# Saving training image 101200.npy
# Image preprocess time: 0:04:56.86
# Saving training image 101300.npy
# Image preprocess time: 0:04:58.08
# Saving training image 101400.npy
# Image preprocess time: 0:04:59.10
# Saving training image 101500.npy
# Image preprocess time: 0:05:00.05
# Saving training image 101600.npy
# Image preprocess time: 0:05:00.96
# Saving training image 101700.npy
# Image preprocess time: 0:05:01.87
# Saving training image 101800.npy
# Image preprocess time: 0:05:03.01
# Saving training image 101900.npy
# Image preprocess time: 0:05:03.86
# Saving training image 102000.npy
# Image preprocess time: 0:05:04.76
# Saving training image 102100.npy
# Image preprocess time: 0:05:05.66
# Saving training image 102200.npy
# Image preprocess time: 0:05:06.55
# Saving training image 102300.npy
# Image preprocess time: 0:05:07.43
# Saving training image 102400.npy
# Image preprocess time: 0:05:08.35
# Saving training image 102500.npy
# Image preprocess time: 0:05:09.64
# Saving training image 102600.npy
# Image preprocess time: 0:05:10.88
# Saving training image 102700.npy
# Image preprocess time: 0:05:12.23
# Saving training image 102800.npy
# Image preprocess time: 0:05:13.62
# Saving training image 102900.npy
# Image preprocess time: 0:05:14.94
# Saving training image 103000.npy
# Image preprocess time: 0:05:16.18
# Saving training image 103100.npy
# Image preprocess time: 0:05:17.47
# Saving training image 103200.npy
# Image preprocess time: 0:05:18.69
# Saving training image 103300.npy
# Image preprocess time: 0:05:19.96
# Saving training image 103400.npy
# Image preprocess time: 0:05:20.90
# Saving training image 103500.npy
# Image preprocess time: 0:05:21.83
# Saving training image 103600.npy
# Image preprocess time: 0:05:22.84
# Saving training image 103700.npy
# Image preprocess time: 0:05:23.77
# Saving training image 103800.npy
# Image preprocess time: 0:05:24.65
# Saving training image 103900.npy
# Image preprocess time: 0:05:25.51
# Saving training image 104000.npy
# Image preprocess time: 0:05:26.41
# Saving training image 104100.npy
# Image preprocess time: 0:05:27.30
# Saving training image 104200.npy
# Image preprocess time: 0:05:28.25
# Saving training image 104300.npy
# Image preprocess time: 0:05:29.09
# Saving training image 104400.npy
# Image preprocess time: 0:05:29.98
# Saving training image 104500.npy
# Image preprocess time: 0:05:31.17
# Saving training image 104600.npy
# Image preprocess time: 0:05:32.49
# Saving training image 104700.npy
# Image preprocess time: 0:05:33.69
# Saving training image 104800.npy
# Image preprocess time: 0:05:35.03
# Saving training image 104900.npy
# Image preprocess time: 0:05:36.23
# Saving training image 105000.npy
# Image preprocess time: 0:05:37.46
# Saving training image 105100.npy
# Image preprocess time: 0:05:38.71
# Saving training image 105200.npy
# Image preprocess time: 0:05:39.89
# Saving training image 105300.npy
# Image preprocess time: 0:05:41.16
# Saving training image 105400.npy
# Image preprocess time: 0:05:42.05
# Saving training image 105500.npy
# Image preprocess time: 0:05:42.91
# Saving training image 105600.npy
# Image preprocess time: 0:05:43.79
# Saving training image 105700.npy
# Image preprocess time: 0:05:44.68
# Saving training image 105800.npy
# Image preprocess time: 0:05:45.57
# Saving training image 105900.npy
# Image preprocess time: 0:05:46.41
# Saving training image 106000.npy
# Image preprocess time: 0:05:47.25
# Saving training image 106100.npy
# Image preprocess time: 0:05:48.39
# Saving training image 106200.npy
# Image preprocess time: 0:05:49.31
# Saving training image 106300.npy
# Image preprocess time: 0:05:50.25
# Saving training image 106400.npy
# Image preprocess time: 0:05:51.11
# Saving training image 106500.npy
# Image preprocess time: 0:05:52.38
# Saving training image 106600.npy
# Image preprocess time: 0:05:53.71
# Saving training image 106700.npy
# Image preprocess time: 0:05:54.96
# Saving training image 106800.npy
# Image preprocess time: 0:05:56.12
# Saving training image 106900.npy
# Image preprocess time: 0:05:57.48
# Saving training image 107000.npy
# Image preprocess time: 0:05:58.76
# Saving training image 107100.npy
# Image preprocess time: 0:05:59.93
# Saving training image 107200.npy
# Image preprocess time: 0:06:00.82
# Saving training image 107300.npy
# Image preprocess time: 0:06:01.71
# Saving training image 107400.npy
# Image preprocess time: 0:06:02.64
# Saving training image 107500.npy
# Image preprocess time: 0:06:03.54
# Saving training image 107600.npy
# Image preprocess time: 0:06:04.42
# Saving training image 107700.npy
# Image preprocess time: 0:06:05.32
# Saving training image 107800.npy
# Image preprocess time: 0:06:06.23
# Saving training image 107900.npy
# Image preprocess time: 0:06:07.16
# Saving training image 108000.npy
# Image preprocess time: 0:06:08.06
# Saving training image 108100.npy
# Image preprocess time: 0:06:09.14
# Complete

# %%
text_path = "/content/data/text_c10/captions"
text_files = sorted(os.listdir(text_path))
#print(text_files)
captions = []
caption_embeddings = np.zeros((len(text_files),300),dtype=np.float32)
for filename in range(len(text_files)):
    path = os.path.join(text_path,text_files[filename])
    #print(path)
    f = open(path,'r')
    data = f.read()
    data = data.split("\n")
    f.close()
    for d in range(1):
      x = data[d].lower()
      #x = x.replace(" ","")
      captions.append(x)
      count = 0
      for t in x:
        try:
          caption_embeddings[filename] += glove_embeddings[t]
          count += 1
        except:
          print(t)
          pass
      caption_embeddings[filename] /= count
    if filename %100 == 0:
      print("-------------Files completed:",filename)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -------------Files completed: 7900
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -------------Files completed: 8000
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -------------Files completed: 8100
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -------------Files completed: 8200

# %%
# saving the caption embeddings numpy
embedding_binary_path = os.path.join('/content/drive/MyDrive/flowers/102flowers',
        f'embedding_data.npy')
print("Saving captions embeddings binary...")
np.save(embedding_binary_path,caption_embeddings)
# Out:
# Saving captions embeddings binary...

# %%
embedding_binary_path = os.path.join('/content/drive/MyDrive/flowers/102flowers',
        f'embedding_data.npy')

# %%
caption_embeddings = np.load(embedding_binary_path)

# %%
caption_embeddings.shape
# Out:
# (8209, 300)

# %%
image_binary_path = "/content/drive/MyDrive/flowers/102flowers/npy64x64/"
images = os.listdir(image_binary_path)

# %%
images[-1]
# Out:
# 'training_data_64_64_108100.npy'

# %%
# Creating a list of all the preprocessed images
final_images = np.load(image_binary_path + images[0])
for i in images[1:]:
  print(i)
  try:
    final_images = np.concatenate([final_images,np.load(image_binary_path + i)],axis = 0)
  except:
    pass
# Out:
# training_data_64_64_100200.npy
# training_data_64_64_100300.npy
# training_data_64_64_100400.npy
# training_data_64_64_100500.npy
# training_data_64_64_100600.npy
# training_data_64_64_100700.npy
# training_data_64_64_100800.npy
# training_data_64_64_100900.npy
# training_data_64_64_101000.npy
# training_data_64_64_101100.npy
# training_data_64_64_101200.npy
# training_data_64_64_101300.npy
# training_data_64_64_101400.npy
# training_data_64_64_101500.npy
# training_data_64_64_101600.npy
# training_data_64_64_101700.npy
# training_data_64_64_101800.npy
# training_data_64_64_101900.npy
# training_data_64_64_102000.npy
# training_data_64_64_102100.npy
# training_data_64_64_102200.npy
# training_data_64_64_102300.npy
# training_data_64_64_102400.npy
# training_data_64_64_102500.npy
# training_data_64_64_102600.npy
# training_data_64_64_102700.npy
# training_data_64_64_102800.npy
# training_data_64_64_102900.npy
# training_data_64_64_103000.npy
# training_data_64_64_103100.npy
# training_data_64_64_103200.npy
# training_data_64_64_103300.npy
# training_data_64_64_103400.npy
# training_data_64_64_103500.npy
# training_data_64_64_103600.npy
# training_data_64_64_103700.npy
# training_data_64_64_103800.npy
# training_data_64_64_103900.npy
# training_data_64_64_104000.npy
# training_data_64_64_104100.npy
# training_data_64_64_104200.npy
# training_data_64_64_104300.npy
# training_data_64_64_104400.npy
# training_data_64_64_104500.npy
# training_data_64_64_104600.npy
# training_data_64_64_104700.npy
# training_data_64_64_104800.npy
# training_data_64_64_104900.npy
# training_data_64_64_105000.npy
# training_data_64_64_105100.npy
# training_data_64_64_105200.npy
# training_data_64_64_105300.npy
# training_data_64_64_105400.npy
# training_data_64_64_105500.npy
# training_data_64_64_105600.npy
# training_data_64_64_105700.npy
# training_data_64_64_105800.npy
# training_data_64_64_105900.npy
# training_data_64_64_106000.npy
# training_data_64_64_106100.npy
# training_data_64_64_106200.npy
# training_data_64_64_106300.npy
# training_data_64_64_106400.npy
# training_data_64_64_106500.npy
# training_data_64_64_106600.npy
# training_data_64_64_106700.npy
# training_data_64_64_106800.npy
# training_data_64_64_106900.npy
# training_data_64_64_107000.npy
# training_data_64_64_107100.npy
# training_data_64_64_107200.npy
# training_data_64_64_107300.npy
# training_data_64_64_107400.npy
# training_data_64_64_107500.npy
# training_data_64_64_107600.npy
# training_data_64_64_107700.npy
# training_data_64_64_107800.npy
# training_data_64_64_107900.npy
# training_data_64_64_108000.npy
# training_data_64_64_108100.npy

# %%
# Creating a dataframe to store the captions
df_captions = pd.DataFrame([])
df_captions['captions'] = captions[:len(final_images)]

# %%
df_captions.head()
# Out:
#                                             captions
# 0  prominent purple stigma,petals are white inc olor
# 1  this flower is blue and green in color, with p...
# 2  outer petals are green in color and klarger,in...
# 3  there are several shapes, sizes, and colors of...
# 4  the stamen are towering over the stigma which ...

# %%
captions[:10]
# Out:
# ['prominent purple stigma,petals are white inc olor',
#  'this flower is blue and green in color, with petals that are oval shaped.',
#  'outer petals are green in color and klarger,inner petals are needle shaped',
#  'there are several shapes, sizes, and colors of petals on this complex flower.',
#  'the stamen are towering over the stigma which cannot be seen.',
#  'this flower is white and purple in color, with petals that are oval shaped.',
#  'the petals of this flower are green with a long stigma',
#  'the blossom has a layer of rounded purple and white petals topped by a layer of fringed purple petals.',
#  'this flower is purple and yellow in color, with petals that are oval shaped.',
#  'the petals on this flower are white with an elaborate pistil.']

# %%
import zipfile
import os

# Specify the path to your zip file
zip_file_path = '/content/drive/MyDrive/text_c10-20240205T075004Z-001.zip'

# Specify the directory where you want to extract the contents
extracted_folder_path = '/content/data'

# Create the extraction folder if it doesn't exist
os.makedirs(extracted_folder_path, exist_ok=True)

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents to the specified directory
    zip_ref.extractall(extracted_folder_path)

print(f"Zip file '{zip_file_path}' has been extracted to '{extracted_folder_path}'.")
# Out:
# Zip file '/content/drive/MyDrive/text_c10-20240205T075004Z-001.zip' has been extracted to '/content/data'.

# %%
df_captions.to_csv("/content/data/text_c10/captions.csv",index=None)

# %%
final_images.shape
# Out:
# (8100, 64, 64, 3)

# %%
df_captions= pd.read_csv("/content/data/text_c10/captions.csv")

# %%
df_captions.head()
# Out:
#                                             captions
# 0  prominent purple stigma,petals are white inc olor
# 1  this flower is blue and green in color, with p...
# 2  outer petals are green in color and klarger,in...
# 3  there are several shapes, sizes, and colors of...
# 4  the stamen are towering over the stigma which ...

# %%
len(captions)
# Out:
# 8209

# %%
#images for testing
save_images_captions = captions[:28].copy()
save_images_embeddings = np.copy(caption_embeddings[:28])
save_images_npy = np.copy(final_images[:28])

# %%
caption_embeddings = caption_embeddings[:final_images.shape[0]]

# %%
caption_embeddings.shape
# Out:
# (8100, 300)

# %%
#shuffling the data for training data set
p = np.random.permutation(len(final_images))

# %%
final_images_shuffled = final_images[p]
final_embeddings_shuffled = caption_embeddings[p]

# %%
final_images_shuffled.shape
# Out:
# (8100, 64, 64, 3)

# %%
final_embeddings_shuffled.shape
# Out:
# (8100, 300)

# %%
# Batch and shuffle the data
# train_dataset = tf.data.Dataset.from_tensor_slices(training_data) \
#     .shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
train_dataset = tf.data.Dataset.from_tensor_slices({'images': final_images,
                                                    'embeddings': caption_embeddings}).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def build_generator_func(seed_size,embedding_size, channels):
  input_seed = Input(shape=seed_size)
  input_embed = Input(shape = embedding_size)
  d0 = Dense(128)(input_embed)
  leaky0 = LeakyReLU(alpha=0.2)(d0)

  merge = Concatenate()([input_seed, leaky0])

  d1 = Dense(4*4*256,activation="relu")(merge)
  reshape = Reshape((4,4,256))(d1)

  upSamp1 = UpSampling2D()(reshape)
  conv2d1 = Conv2DTranspose(256,kernel_size=5,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp1)
  batchNorm1 = BatchNormalization(momentum=0.8)(conv2d1)
  leaky1 = LeakyReLU(alpha=0.2)(batchNorm1)

  upSamp2 = UpSampling2D()(leaky1)
  conv2d2 = Conv2DTranspose(256,kernel_size=5,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp2)
  batchNorm2 = BatchNormalization(momentum=0.8)(conv2d2)
  leaky2 = LeakyReLU(alpha=0.2)(batchNorm2)

  upSamp3 = UpSampling2D()(leaky2)
  conv2d3 = Conv2DTranspose(128,kernel_size=4,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp3)
  batchNorm3 = BatchNormalization(momentum=0.8)(conv2d3)
  leaky3 = LeakyReLU(alpha=0.2)(batchNorm3)

  upSamp4 = UpSampling2D(size=(GENERATE_RES,GENERATE_RES))(leaky3)
  conv2d4 = Conv2DTranspose(128,kernel_size=4,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp4)
  batchNorm4 = BatchNormalization(momentum=0.8)(conv2d4)
  leaky4 = LeakyReLU(alpha=0.2)(batchNorm4)

  outputConv = Conv2DTranspose(channels,kernel_size=3,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(leaky4)
  outputActi = Activation("tanh")(outputConv)

  model = Model(inputs=[input_seed,input_embed], outputs=outputActi)
  return model

# %%
def build_discriminator_func(image_shape, embedding_size):
  input_shape = Input(shape=image_shape)
  input_embed = Input(shape=embedding_size)

  conv2d1 = Conv2D(32,kernel_size=4,strides=2,input_shape=image_shape,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(input_shape)
  leaky1 = LeakyReLU(alpha=0.2)(conv2d1)

  drop2 = Dropout(0.25)(leaky1)
  conv2d2 = Conv2D(64, kernel_size=4, strides=2, padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop2)
  batchNorm2 = BatchNormalization(momentum=0.8)(conv2d2)
  leaky2 = LeakyReLU(alpha=0.2)(batchNorm2)

  drop3 = Dropout(0.25)(leaky2)
  conv2d3 = Conv2D(128, kernel_size=4, strides=2, padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop3)
  batchNorm3 = BatchNormalization(momentum=0.8)(conv2d3)
  leaky3 = LeakyReLU(alpha=0.2)(batchNorm3)

  drop4 = Dropout(0.25)(leaky3)
  conv2d4 = Conv2D(256, kernel_size=4, strides=2, padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop4)
  batchNorm4 = BatchNormalization(momentum=0.8)(conv2d4)
  leaky4 = LeakyReLU(alpha=0.2)(batchNorm4)

  dense_embed = Dense(128,kernel_initializer=initializers.RandomNormal(stddev=0.02))(input_embed)
  leaky_embed = LeakyReLU(alpha=0.2)(dense_embed)
  reshape_embed = Reshape((4,4,8))(leaky_embed)
  merge_embed = Concatenate()([leaky4, reshape_embed])

  drop5 = Dropout(0.25)(merge_embed)
  conv2d5 = Conv2D(512, kernel_size=4,kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop5)
  batchNorm5 = BatchNormalization(momentum=0.8)(conv2d5)
  leaky5 = LeakyReLU(alpha=0.2)(batchNorm5)

  drop6 = Dropout(0.25)(leaky5)
  flatten = Flatten()(drop6)
  output = Dense(1,activation="sigmoid")(flatten)

  model = Model(inputs=[input_shape,input_embed], outputs=output)
  return model

# %%
#Function to save image samples generated
def save_images(cnt,noise,embeds):
  image_array = np.full((
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)),
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3),
      255, dtype=np.uint8)

  generated_images = generator.predict((noise,embeds))

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] \
            = generated_images[image_count] * 255
        image_count += 1


  output_path = "/content/drive/MyDrive/flowers/102flowers/images_generated_during_training_100"
  if not os.path.exists(output_path):
    os.makedirs(output_path)

  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
import zipfile
import os

# Specify the path to your zip file
zip_file_path = '/content/drive/MyDrive/model-20240210T025539Z-001.zip'

# Specify the directory where you want to extract the contents
extracted_folder_path = '/content/drive/MyDrive/flowers/102flowers/model'

# Create the extraction folder if it doesn't exist
os.makedirs(extracted_folder_path, exist_ok=True)

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents to the specified directory
    zip_ref.extractall(extracted_folder_path)

print(f"Zip file '{zip_file_path}' has been extracted to '{extracted_folder_path}'.")
# Out:
# Zip file '/content/drive/MyDrive/model-20240210T025539Z-001.zip' has been extracted to '/content/drive/MyDrive/flowers/102flowers/model'.

# %%
# Initlializing a generator
generator = build_generator_func(SEED_SIZE,EMBEDDING_SIZE, IMAGE_CHANNELS)
generator.load_weights("/content/drive/MyDrive/flowers/102flowers/model/model/text_to_image_generator_cub_character.h5")

# %%
# Sample output from the Generator
noise = tf.random.normal([1, 100])
generated_image = generator((noise,caption_embeddings[5].reshape(1,300)), training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
# Initlializing a discriminator
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator_func(image_shape,EMBEDDING_SIZE)
discriminator.load_weights("/content/drive/MyDrive/flowers/102flowers/model/model/text_to_image_disc_cub_character.h5")

# %%
decision = discriminator((generated_image,caption_embeddings[5].reshape(1,300)))
print(decision)
# Out:
# tf.Tensor([[0.2823987]], shape=(1, 1), dtype=float32)

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_image_real_text, fake_image_real_text, real_image_fake_text):
    real_loss = cross_entropy(tf.random.uniform(real_image_real_text.shape,0.8,1.0), real_image_real_text)
    fake_loss = (cross_entropy(tf.random.uniform(fake_image_real_text.shape,0.0,0.2), fake_image_real_text) +
                 cross_entropy(tf.random.uniform(real_image_fake_text.shape,0.0,0.2), real_image_fake_text))/2

    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(learning_rate=2.0e-4,beta_1 = 0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate=2.0e-4,beta_1 = 0.5)

# %%
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images,captions,fake_captions):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE],dtype=tf.float32)

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator((seed,captions), training=True)
    real_image_real_text = discriminator((images,captions), training=True)
    real_image_fake_text = discriminator((images,fake_captions), training=True)
    fake_image_real_text = discriminator((generated_images,captions), training=True)

    gen_loss = generator_loss(fake_image_real_text)
    disc_loss = discriminator_loss(real_image_real_text, fake_image_real_text, real_image_fake_text)
    # print(gen_loss)
    # print(disc_loss)

    gradients_of_generator = gen_tape.gradient(\
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(\
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator,
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
# Function that executes trianing process
def train(train_dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS,
                                       SEED_SIZE))
  fixed_embed = save_images_embeddings

  start = time.time()

  for epoch in range(epochs):
    print("epoch start...")
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for batch in train_dataset[:-1]:
      train_batch = batch['images']
      caption_batch = batch['embeddings']

      fake_caption_batch = np.copy(caption_batch)
      np.random.shuffle(fake_caption_batch)

      t = train_step(train_batch,caption_batch,fake_caption_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])
    print("now")
    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print(f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss}, {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed,fixed_embed)

    generator.save(os.path.join(MODEL_PATH,"text_to_image_generator_cub_character.h5"))
    discriminator.save(os.path.join(MODEL_PATH,"text_to_image_disc_cub_character.h5"))
    print("model saved")

# %%
train(list(train_dataset.as_numpy_iterator()), 100)
# Out:
# epoch start...
# now
# Epoch 1, gen loss=1.4756207466125488,disc loss=1.141563892364502, 0:00:47.07
# 1/1 [==============================] - 1s 1s/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 2, gen loss=1.4699888229370117,disc loss=1.1042649745941162, 0:00:26.88
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 3, gen loss=1.472951054573059,disc loss=1.092898964881897, 0:00:27.48
# 1/1 [==============================] - 0s 33ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 4, gen loss=1.4000513553619385,disc loss=1.076169490814209, 0:00:27.36
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 5, gen loss=1.4171030521392822,disc loss=1.0910334587097168, 0:00:27.19
# 1/1 [==============================] - 0s 29ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 6, gen loss=1.4392952919006348,disc loss=1.065048098564148, 0:00:27.31
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 7, gen loss=1.4644241333007812,disc loss=1.059004545211792, 0:00:27.36
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 8, gen loss=1.574375867843628,disc loss=1.026038408279419, 0:00:27.33
# 1/1 [==============================] - 0s 26ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 9, gen loss=1.6526769399642944,disc loss=1.000610589981079, 0:00:27.26
# 1/1 [==============================] - 0s 21ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 10, gen loss=1.7305229902267456,disc loss=0.9888402819633484, 0:00:27.21
# 1/1 [==============================] - 0s 30ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 11, gen loss=1.7370855808258057,disc loss=0.9736725687980652, 0:00:27.28
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 12, gen loss=1.6681963205337524,disc loss=1.004790186882019, 0:00:27.27
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 13, gen loss=1.6948081254959106,disc loss=1.0023754835128784, 0:00:27.23
# 1/1 [==============================] - 0s 31ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 14, gen loss=1.5784176588058472,disc loss=1.0217210054397583, 0:00:27.30
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 15, gen loss=1.691919207572937,disc loss=0.9962844252586365, 0:00:27.34
# 1/1 [==============================] - 0s 32ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 16, gen loss=1.5451680421829224,disc loss=1.0074963569641113, 0:00:27.34
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 17, gen loss=1.6649922132492065,disc loss=1.009966254234314, 0:00:27.28
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 18, gen loss=1.6002074480056763,disc loss=1.0024018287658691, 0:00:27.31
# 1/1 [==============================] - 0s 31ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 19, gen loss=1.6100423336029053,disc loss=1.012458086013794, 0:00:27.32
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 20, gen loss=1.6530297994613647,disc loss=0.9907934069633484, 0:00:27.37
# 1/1 [==============================] - 0s 31ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 21, gen loss=1.6920355558395386,disc loss=1.0060302019119263, 0:00:27.29
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 22, gen loss=1.5913593769073486,disc loss=1.012485146522522, 0:00:27.27
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 23, gen loss=1.5874310731887817,disc loss=1.0005296468734741, 0:00:27.33
# 1/1 [==============================] - 0s 32ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 24, gen loss=1.5625691413879395,disc loss=1.0172277688980103, 0:00:27.36
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 25, gen loss=1.5229260921478271,disc loss=1.0190069675445557, 0:00:27.27
# 1/1 [==============================] - 0s 29ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 26, gen loss=1.596325397491455,disc loss=0.9994691014289856, 0:00:27.29
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 27, gen loss=1.541689395904541,disc loss=1.0115541219711304, 0:00:27.34
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 28, gen loss=1.5907694101333618,disc loss=0.9947186708450317, 0:00:27.30
# 1/1 [==============================] - 0s 35ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 29, gen loss=1.6002930402755737,disc loss=0.9978666305541992, 0:00:27.33
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 30, gen loss=1.5911909341812134,disc loss=1.013264775276184, 0:00:27.30
# 1/1 [==============================] - 0s 29ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 31, gen loss=1.5882105827331543,disc loss=1.0042037963867188, 0:00:27.28
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 32, gen loss=1.6082689762115479,disc loss=0.9805159568786621, 0:00:27.32
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 33, gen loss=1.5658046007156372,disc loss=0.9935888648033142, 0:00:27.29
# 1/1 [==============================] - 0s 33ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 34, gen loss=1.6167410612106323,disc loss=1.0037387609481812, 0:00:27.27
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 35, gen loss=1.6028717756271362,disc loss=1.0029683113098145, 0:00:27.26
# 1/1 [==============================] - 0s 33ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 36, gen loss=1.6565775871276855,disc loss=0.970451831817627, 0:00:27.33
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 37, gen loss=1.6877363920211792,disc loss=0.985366940498352, 0:00:27.33
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 38, gen loss=1.628368854522705,disc loss=0.9875829219818115, 0:00:27.32
# 1/1 [==============================] - 0s 30ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 39, gen loss=1.7221757173538208,disc loss=0.968721330165863, 0:00:27.26
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 40, gen loss=1.8000036478042603,disc loss=0.9632317423820496, 0:00:27.32
# 1/1 [==============================] - 0s 32ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 41, gen loss=1.6687910556793213,disc loss=0.9992659091949463, 0:00:27.34
# 1/1 [==============================] - 0s 31ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 42, gen loss=1.649816870689392,disc loss=0.9861947298049927, 0:00:27.30
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 43, gen loss=1.6750508546829224,disc loss=0.9743725061416626, 0:00:27.23
# 1/1 [==============================] - 0s 32ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 44, gen loss=1.6613115072250366,disc loss=0.9811038374900818, 0:00:27.32
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 45, gen loss=1.6158860921859741,disc loss=0.9911837577819824, 0:00:27.24
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 46, gen loss=1.6367239952087402,disc loss=0.9736626148223877, 0:00:27.30
# 1/1 [==============================] - 0s 32ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 47, gen loss=1.7839056253433228,disc loss=0.9607467651367188, 0:00:27.35
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 48, gen loss=1.7592525482177734,disc loss=0.9605318307876587, 0:00:27.27
# 1/1 [==============================] - 0s 29ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 49, gen loss=1.728698968887329,disc loss=0.9662505388259888, 0:00:27.32
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 50, gen loss=1.673923134803772,disc loss=0.9796887040138245, 0:00:27.34
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 51, gen loss=1.6544158458709717,disc loss=0.9655501842498779, 0:00:27.28
# 1/1 [==============================] - 0s 29ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 52, gen loss=1.781543254852295,disc loss=0.9614553451538086, 0:00:27.33
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 53, gen loss=1.7584582567214966,disc loss=0.9768852591514587, 0:00:27.35
# 1/1 [==============================] - 0s 39ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 54, gen loss=1.736295223236084,disc loss=0.9512037038803101, 0:00:27.31
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 55, gen loss=1.8710230588912964,disc loss=0.9515190124511719, 0:00:27.29
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 56, gen loss=1.784594178199768,disc loss=0.950806736946106, 0:00:27.25
# 1/1 [==============================] - 0s 30ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 57, gen loss=1.7513623237609863,disc loss=0.9591599106788635, 0:00:27.33
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 58, gen loss=1.7990024089813232,disc loss=0.9447898268699646, 0:00:27.25
# 1/1 [==============================] - 0s 31ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 59, gen loss=1.859217643737793,disc loss=0.9428409934043884, 0:00:27.29
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 60, gen loss=1.7349077463150024,disc loss=0.9630461931228638, 0:00:27.24
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 61, gen loss=1.7690272331237793,disc loss=0.952739953994751, 0:00:27.26
# 1/1 [==============================] - 0s 32ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 62, gen loss=1.8302810192108154,disc loss=0.9484059810638428, 0:00:27.28
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 63, gen loss=1.6715078353881836,disc loss=0.9730443358421326, 0:00:27.23
# 1/1 [==============================] - 0s 30ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 64, gen loss=1.6857346296310425,disc loss=0.9653642177581787, 0:00:27.26
# 1/1 [==============================] - 0s 28ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 65, gen loss=1.7127292156219482,disc loss=0.9538483619689941, 0:00:27.32
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 66, gen loss=1.7538455724716187,disc loss=0.961098313331604, 0:00:27.26
# 1/1 [==============================] - 0s 30ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 67, gen loss=1.7284246683120728,disc loss=0.9684313535690308, 0:00:27.30
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 68, gen loss=1.6591295003890991,disc loss=0.9704986810684204, 0:00:27.26
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 69, gen loss=1.7228015661239624,disc loss=0.9633724093437195, 0:00:27.20
# 1/1 [==============================] - 0s 29ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 70, gen loss=1.785370111465454,disc loss=0.9494675993919373, 0:00:27.34
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 71, gen loss=1.8736881017684937,disc loss=0.9397007822990417, 0:00:27.17
# 1/1 [==============================] - 0s 32ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 72, gen loss=1.870775818824768,disc loss=0.940840482711792, 0:00:27.17
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 73, gen loss=1.7415153980255127,disc loss=0.9485058188438416, 0:00:27.27
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 74, gen loss=1.7403477430343628,disc loss=0.9556727409362793, 0:00:27.24
# 1/1 [==============================] - 0s 35ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 75, gen loss=1.814336895942688,disc loss=0.9378469586372375, 0:00:27.22
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 76, gen loss=1.8376965522766113,disc loss=0.9349508881568909, 0:00:27.24
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 77, gen loss=1.879223108291626,disc loss=0.9386509656906128, 0:00:27.22
# 1/1 [==============================] - 0s 35ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 78, gen loss=1.757653832435608,disc loss=0.9569705128669739, 0:00:27.25
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 79, gen loss=1.7894662618637085,disc loss=0.9508165717124939, 0:00:27.32
# 1/1 [==============================] - 0s 32ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 80, gen loss=1.7222568988800049,disc loss=0.9646694660186768, 0:00:27.22
# 1/1 [==============================] - 0s 29ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 81, gen loss=1.7476080656051636,disc loss=0.9464946389198303, 0:00:27.30
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 82, gen loss=1.8192358016967773,disc loss=0.9390106201171875, 0:00:27.23
# 1/1 [==============================] - 0s 31ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 83, gen loss=1.7620505094528198,disc loss=0.9431767463684082, 0:00:27.23
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 84, gen loss=1.7962967157363892,disc loss=0.9543091654777527, 0:00:27.29
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 85, gen loss=1.7102693319320679,disc loss=0.9660125374794006, 0:00:27.22
# 1/1 [==============================] - 0s 33ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 86, gen loss=1.7672702074050903,disc loss=0.9441328048706055, 0:00:27.22
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 87, gen loss=1.7887591123580933,disc loss=0.941539466381073, 0:00:27.27
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 88, gen loss=1.7853730916976929,disc loss=0.9582582712173462, 0:00:27.24
# 1/1 [==============================] - 0s 33ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 89, gen loss=1.804500937461853,disc loss=0.9393023252487183, 0:00:27.24
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 90, gen loss=1.7886005640029907,disc loss=0.9358858466148376, 0:00:27.25
# 1/1 [==============================] - 0s 29ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 91, gen loss=1.8408950567245483,disc loss=0.9482116103172302, 0:00:27.24
# 1/1 [==============================] - 0s 28ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 92, gen loss=1.8954179286956787,disc loss=0.9238008260726929, 0:00:27.23
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 93, gen loss=1.8199983835220337,disc loss=0.936741828918457, 0:00:27.26
# 1/1 [==============================] - 0s 30ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 94, gen loss=1.731884241104126,disc loss=0.9526349902153015, 0:00:27.24
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 95, gen loss=1.8806917667388916,disc loss=0.9382622838020325, 0:00:27.28
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 96, gen loss=1.7912817001342773,disc loss=0.9485330581665039, 0:00:27.26
# 1/1 [==============================] - 0s 30ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 97, gen loss=1.6752463579177856,disc loss=0.9533511400222778, 0:00:27.26
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 98, gen loss=1.7545002698898315,disc loss=0.9553233981132507, 0:00:27.24
# 1/1 [==============================] - 0s 21ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 99, gen loss=1.8644887208938599,disc loss=0.92213374376297, 0:00:27.27
# 1/1 [==============================] - 0s 26ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 100, gen loss=1.8515673875808716,disc loss=0.932051420211792, 0:00:27.24
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved

# %%
#Retriving embeddings for testing the results
save_images_embeddings.shape
# Out:
# (28, 300)

# %%
# Printing the captions
save_images_captions
# Out:
# ['prominent purple stigma,petals are white inc olor',
#  'this flower is blue and green in color, with petals that are oval shaped.',
#  'outer petals are green in color and klarger,inner petals are needle shaped',
#  'there are several shapes, sizes, and colors of petals on this complex flower.',
#  'the stamen are towering over the stigma which cannot be seen.',
#  'this flower is white and purple in color, with petals that are oval shaped.',
#  'the petals of this flower are green with a long stigma',
#  'the blossom has a layer of rounded purple and white petals topped by a layer of fringed purple petals.',
#  'this flower is purple and yellow in color, with petals that are oval shaped.',
#  'the petals on this flower are white with an elaborate pistil.',
#  'this flower has petals that are pink with stringy white stamen',
#  'this flower has star shaped white petals as its main feature.',
#  'lower petals are white in color,and larger in size,inner petals are purple in clor',
#  'this flower has petals in the shape of a circle and are purple and stringy',
#  'a unique looking flower that has multiple colors and long petals',
#  'this flower is white and purple in color, with petals that are oval shaped.',
#  'this flower is white in color, with petals that are oval shaped.',
#  'this flower has thick star shaped maroon petals as its main feature.',
#  'this flower has petals that are white with purple stringy stamen',
#  'the pistil is white and is very noticeable, and the petals are purple.',
#  'purple flower with curvy string-like petals and a group of large yellow stamen in the center.',
#  'this flower has an elaborate golden stamen and two different types of purple petals.',
#  'flower with white long white petals and very long purple stamen',
#  'this flower is blue and white in color, with petals that are oval shaped.',
#  'leaves are green in color,outer petals are white green in color',
#  'the petals of the flower are pink in color and have filaments that are pink in color.',
#  'this is a purple flower with long purple anthers on it.',
#  'this is a strange flower with purple petals and a white stigma.']

# %%
#Function to save generated image after we provide the text and save it in a grid
def save_test_images(cnt,noise,embeds):
  image_array = np.full((
      TEST_MARGIN + (TEST_ROWS * (GENERATE_SQUARE+TEST_MARGIN)),
      TEST_MARGIN + (TEST_COLS * (GENERATE_SQUARE+TEST_MARGIN)), 3),
      255, dtype=np.uint8)

  generated_test_images = generator.predict((noise,embeds))

  generated_test_images = 0.5 * generated_test_images + 0.5

  image_count = 0
  for row in range(TEST_ROWS):
      for col in range(TEST_COLS):
        r = row * (GENERATE_SQUARE+16) + TEST_MARGIN
        c = col * (GENERATE_SQUARE+16) + TEST_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] \
            = generated_test_images[image_count] * 255
        image_count += 1


  output_path = "/content/drive/MyDrive/flowers/102flowers/generated_test_output"
  if not os.path.exists(output_path):
    os.makedirs(output_path)

  filename = os.path.join(output_path,f"TEST-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
def test_image(text,num):
  test_embeddings = np.zeros((1,300),dtype=np.float32)

  x = text.lower()
  #x = x.replace(" ","")
  count = 0
  for t in x:
    try:
      test_embeddings[0] += glove_embeddings[t]
      count += 1
    except:
      print(t)
      pass
  test_embeddings[0] /= count
  test_embeddings =  np.repeat(test_embeddings,[28],axis=0)
  noise = tf.random.normal([28, 100])
  save_test_images(num,noise,test_embeddings)

# %%
test_image("this is a pink flower with oval shaped petals",25)
# Out:
#
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 20ms/step

# %%
import IPython
IPython.display.Image('/content/drive/MyDrive/flowers/102flowers/generated_test_output/TEST-25.png')

# %%
test_image("a flower with black petals and white stem",25)
# Out:
#
#
#
#
#
#
#
# 1/1 [==============================] - 0s 33ms/step

# %%
import IPython
IPython.display.Image('/content/drive/MyDrive/flowers/102flowers/generated_test_output/TEST-25.png')
